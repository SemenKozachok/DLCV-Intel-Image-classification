# %%
import numpy as np
import os
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
import seaborn as sns
from copy import deepcopy

# %%
ds_path = "datasets/Intel Image Classification/"
train_path = os.path.join(ds_path, "seg_train")
test_path = os.path.join(ds_path, "seg_test")

classes = os.listdir(train_path)
classes # classes of the dataset
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
BATCHSIZE = 32
N_WORKERS = 2

# %%
test_transform = transforms.Compose([
    transforms.Resize((150, 150)),  
    transforms.ToTensor(),          
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))  
])

full_train_ds = datasets.ImageFolder(root=train_path, transform=test_transform)
test_ds = datasets.ImageFolder(root=test_path, transform=test_transform)

train_ds, val_ds = random_split(full_train_ds, [0.8, 0.2])

# %%
test_loader = DataLoader(test_ds, batch_size=BATCHSIZE, shuffle=False)
train_loader = DataLoader(train_ds, batch_size=BATCHSIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCHSIZE, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def train_model(model, train_loader, val_loader, n_epochs=10, print_progress=True, dynamic_lr=False, scheduler=None):

    train_losses, train_accs, train_f1s = [], [], []
    val_losses, val_accs, val_f1s = [], [], []
    
    for epoch in range(n_epochs):
        ### --- TRAINING PHASE --- ###
        model.train()
        train_loss = 0.0
        y_true_train = np.zeros(len(train_ds), dtype=int)
        y_pred_train = np.zeros(len(train_ds), dtype=int)

        index = 0
        for images, labels in train_loader:
            batch_size = labels.size(0) 
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs, 1)
            y_true_train[index : index + batch_size] = labels.cpu().numpy()
            y_pred_train[index : index + batch_size] = predicted.cpu().numpy()
            index += batch_size
            
        train_acc = accuracy_score(y_true_train, y_pred_train)
        train_f1 = f1_score(y_true_train, y_pred_train, average="weighted")
        
        train_loss = train_loss/len(train_ds)
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        train_f1s.append(train_f1)
        
        ### --- VALIDATION PHASE --- ###
        model.eval()
        val_loss = 0.0
        y_true_val = np.zeros(len(val_ds), dtype=int)
        y_pred_val = np.zeros(len(val_ds), dtype=int)
        with torch.no_grad():  
            index = 0
            for images, labels in val_loader:
                batch_size = labels.size(0) 
                images, labels = images.to(device), labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * images.size(0)
                _, predicted = torch.max(outputs, 1)
                y_true_val[index : index + batch_size] = labels.cpu().numpy()
                y_pred_val[index : index + batch_size] = predicted.cpu().numpy()
                index += batch_size

        val_acc = accuracy_score(y_true_val, y_pred_val)
        val_f1 = f1_score(y_true_val, y_pred_val, average="weighted")

        val_loss = val_loss/len(val_ds)
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        val_f1s.append(val_f1)

        if dynamic_lr:
            scheduler.step()
            print(f"Current LR: {optimizer.param_groups[0]['lr']:.6f}")
            
        if print_progress:
            print(f"Epoch [{epoch+1}/{n_epochs}]: "
                  f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f} | "
                  f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}")
    
    if print_progress:
        print("Training Complete!")
    return train_losses, train_accs, train_f1s, val_losses, val_accs, val_f1s

# %%
def visualize_scores(metrics):
    # Unpack metrics
    train_losses, train_accs, train_f1s, val_losses, val_accs, val_f1s = metrics
    epochs = range(1, len(train_losses) + 1)
    
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    # Plot Loss
    axes[0].plot(epochs, train_losses, label="Train Loss")
    axes[0].plot(epochs, val_losses, label="Val Loss")
    axes[0].set_title("Loss")
    axes[0].set_xlabel("Epochs")
    axes[0].set_ylabel("Loss")
    axes[0].grid(visible=True)
    axes[0].legend()

    # Plot Accuracy
    axes[1].plot(epochs, train_accs, label="Train Accuracy")
    axes[1].plot(epochs, val_accs, label="Val Accuracy")
    axes[1].set_title("Accuracy")
    axes[1].set_xlabel("Epochs")
    axes[1].set_ylabel("Accuracy")
    axes[1].grid(visible=True)
    axes[1].legend()

    # Plot F1-score
    axes[2].plot(epochs, train_f1s, label="Train F1-score")
    axes[2].plot(epochs, val_f1s, label="Val F1-score")
    axes[2].set_title("F1-score")
    axes[2].set_xlabel("Epochs")
    axes[2].set_ylabel("F1-score")
    axes[2].grid(visible=True)
    axes[2].legend()

    plt.tight_layout()
    plt.show()

# %%
def conf_matrices(y_true_train, y_pred_train, y_true_val, y_pred_val, class_names):
    # Compute confusion matrices
    cm_train = confusion_matrix(y_true_train, y_pred_train)
    cm_val = confusion_matrix(y_true_val, y_pred_val)

    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # Plot Train Confusion Matrix
    sns.heatmap(cm_train, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names, ax=axes[0])
    axes[0].set_title("Train Confusion Matrix")
    axes[0].set_xlabel("Predicted Labels")
    axes[0].set_ylabel("True Labels")

    # Plot Validation Confusion Matrix
    sns.heatmap(cm_val, annot=True, fmt="d", cmap="Oranges", xticklabels=class_names, yticklabels=class_names, ax=axes[1])
    axes[1].set_title("Validation Confusion Matrix")
    axes[1].set_xlabel("Predicted Labels")
    axes[1].set_ylabel("True Labels")

    plt.tight_layout()
    plt.show()

# %%
def get_predictions(model, dataloader):

    model.eval()  
    y_true = []
    y_pred = []

    with torch.no_grad():  
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)  
            outputs = model(images)  
            _, predicted = torch.max(outputs, 1)  
            
            y_true.extend(labels.cpu().numpy())  
            y_pred.extend(predicted.cpu().numpy())  

    return np.array(y_true), np.array(y_pred)

# %%
def visualize(model, metrics):
        visualize_scores(metrics)
        val_true, val_pred = get_predictions(model, val_loader)
        train_true, train_pred = get_predictions(model, train_loader)
        conf_matrices(train_true, train_pred, val_true, val_pred, classes)

# %%
class CNN_3blocks(nn.Module):
    def __init__(self, n_classes=6):
        super(CNN_3blocks, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1)

        self.bn1 = nn.BatchNorm2d(32)
        self.bn2 = nn.BatchNorm2d(64)
        self.bn3 = nn.BatchNorm2d(64)
        self.bn4 = nn.BatchNorm2d(128)
        self.bn5 = nn.BatchNorm2d(128)
        self.bn6 = nn.BatchNorm2d(256)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.fc1 = nn.Linear(256 * 18 * 18, 512)  
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, n_classes)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x = self.pool(x)
        x = F.relu(self.bn5(self.conv5(x)))
        x = F.relu(self.bn6(self.conv6(x)))
        x = self.pool(x)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)  

        return x

# %%
train_transform = transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_ds.dataset = deepcopy(train_ds.dataset)
train_ds.dataset.transform = train_transform

# %%
model_v4 = CNN_3blocks(6).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_v4.parameters(), lr=10e-4)

# %%
# %%time 
EPOCHS = 30
metrics_v4 = train_model(model_v4, train_loader, val_loader, EPOCHS)
# Out:
# Epoch [1/30]: Train Loss: 1.4636, Train Acc: 0.54 | Val Loss: 0.9293, Val Acc: 0.65
# Epoch [2/30]: Train Loss: 0.7770, Train Acc: 0.70 | Val Loss: 0.8312, Val Acc: 0.69
# Epoch [3/30]: Train Loss: 0.6512, Train Acc: 0.76 | Val Loss: 0.6075, Val Acc: 0.79
# Epoch [4/30]: Train Loss: 0.5850, Train Acc: 0.78 | Val Loss: 0.6781, Val Acc: 0.74
# Epoch [5/30]: Train Loss: 0.5440, Train Acc: 0.80 | Val Loss: 0.5447, Val Acc: 0.81
# Epoch [6/30]: Train Loss: 0.5039, Train Acc: 0.81 | Val Loss: 0.4239, Val Acc: 0.85
# Epoch [7/30]: Train Loss: 0.4802, Train Acc: 0.83 | Val Loss: 0.4815, Val Acc: 0.82
# Epoch [8/30]: Train Loss: 0.4576, Train Acc: 0.83 | Val Loss: 0.4526, Val Acc: 0.84
# Epoch [9/30]: Train Loss: 0.4422, Train Acc: 0.84 | Val Loss: 0.5273, Val Acc: 0.82
# Epoch [10/30]: Train Loss: 0.4198, Train Acc: 0.85 | Val Loss: 0.4477, Val Acc: 0.85
# Epoch [11/30]: Train Loss: 0.3984, Train Acc: 0.86 | Val Loss: 0.4200, Val Acc: 0.86
# Epoch [12/30]: Train Loss: 0.3922, Train Acc: 0.86 | Val Loss: 0.5209, Val Acc: 0.82
# Epoch [13/30]: Train Loss: 0.3707, Train Acc: 0.86 | Val Loss: 0.4119, Val Acc: 0.86
# Epoch [14/30]: Train Loss: 0.3443, Train Acc: 0.88 | Val Loss: 0.3911, Val Acc: 0.87
# Epoch [15/30]: Train Loss: 0.3517, Train Acc: 0.87 | Val Loss: 0.3709, Val Acc: 0.87
# Epoch [16/30]: Train Loss: 0.3347, Train Acc: 0.88 | Val Loss: 0.3946, Val Acc: 0.87
# Epoch [17/30]: Train Loss: 0.3087, Train Acc: 0.89 | Val Loss: 0.3824, Val Acc: 0.87
# Epoch [18/30]: Train Loss: 0.3209, Train Acc: 0.89 | Val Loss: 0.3698, Val Acc: 0.88
# Epoch [19/30]: Train Loss: 0.3013, Train Acc: 0.89 | Val Loss: 0.3907, Val Acc: 0.87
# Epoch [20/30]: Train Loss: 0.2892, Train Acc: 0.89 | Val Loss: 0.4448, Val Acc: 0.86
# Epoch [21/30]: Train Loss: 0.2753, Train Acc: 0.90 | Val Loss: 0.4271, Val Acc: 0.86
# Epoch [22/30]: Train Loss: 0.2647, Train Acc: 0.90 | Val Loss: 0.3701, Val Acc: 0.88
# Epoch [23/30]: Train Loss: 0.2562, Train Acc: 0.91 | Val Loss: 0.4038, Val Acc: 0.87
# Epoch [24/30]: Train Loss: 0.2425, Train Acc: 0.91 | Val Loss: 0.4015, Val Acc: 0.89
# Epoch [25/30]: Train Loss: 0.2363, Train Acc: 0.91 | Val Loss: 0.3869, Val Acc: 0.87
# Epoch [26/30]: Train Loss: 0.2336, Train Acc: 0.92 | Val Loss: 0.3921, Val Acc: 0.88
# Epoch [27/30]: Train Loss: 0.2144, Train Acc: 0.92 | Val Loss: 0.4203, Val Acc: 0.88
# Epoch [28/30]: Train Loss: 0.2148, Train Acc: 0.92 | Val Loss: 0.4900, Val Acc: 0.86
# Epoch [29/30]: Train Loss: 0.2090, Train Acc: 0.92 | Val Loss: 0.4468, Val Acc: 0.86
# Epoch [30/30]: Train Loss: 0.1972, Train Acc: 0.93 | Val Loss: 0.4234, Val Acc: 0.88
# Training Complete!
# CPU times: total: 2h 32min 44s
# Wall time: 37min 33s

# %%
visualize(model_v4, metrics_v4)

# %%
# %%time 
EPOCHS = 20
metrics_v4_2 = train_model(model_v4, train_loader, val_loader, EPOCHS)
# Out:
# Epoch [1/20]: Train Loss: 0.1783, Train Acc: 0.94 | Val Loss: 0.4678, Val Acc: 0.86
# Epoch [2/20]: Train Loss: 0.1844, Train Acc: 0.94 | Val Loss: 0.4581, Val Acc: 0.87
# Epoch [3/20]: Train Loss: 0.1798, Train Acc: 0.93 | Val Loss: 0.4144, Val Acc: 0.89
# Epoch [4/20]: Train Loss: 0.1634, Train Acc: 0.94 | Val Loss: 0.4235, Val Acc: 0.88
# Epoch [5/20]: Train Loss: 0.1592, Train Acc: 0.94 | Val Loss: 0.4189, Val Acc: 0.89
# Epoch [6/20]: Train Loss: 0.1371, Train Acc: 0.95 | Val Loss: 0.5943, Val Acc: 0.87
# Epoch [7/20]: Train Loss: 0.1399, Train Acc: 0.95 | Val Loss: 0.4792, Val Acc: 0.87
# Epoch [8/20]: Train Loss: 0.1437, Train Acc: 0.95 | Val Loss: 0.4530, Val Acc: 0.88
# Epoch [9/20]: Train Loss: 0.1382, Train Acc: 0.95 | Val Loss: 0.4378, Val Acc: 0.89
# Epoch [10/20]: Train Loss: 0.1332, Train Acc: 0.95 | Val Loss: 0.5424, Val Acc: 0.87
# Epoch [11/20]: Train Loss: 0.1179, Train Acc: 0.96 | Val Loss: 0.5067, Val Acc: 0.88
# Epoch [12/20]: Train Loss: 0.1151, Train Acc: 0.96 | Val Loss: 0.5177, Val Acc: 0.88
# Epoch [13/20]: Train Loss: 0.1070, Train Acc: 0.96 | Val Loss: 0.5488, Val Acc: 0.88
# Epoch [14/20]: Train Loss: 0.1153, Train Acc: 0.96 | Val Loss: 0.5736, Val Acc: 0.87
# Epoch [15/20]: Train Loss: 0.1002, Train Acc: 0.96 | Val Loss: 0.5653, Val Acc: 0.88
# Epoch [16/20]: Train Loss: 0.0870, Train Acc: 0.97 | Val Loss: 0.5603, Val Acc: 0.88
# Epoch [17/20]: Train Loss: 0.0959, Train Acc: 0.97 | Val Loss: 0.5791, Val Acc: 0.88
# Epoch [18/20]: Train Loss: 0.0972, Train Acc: 0.96 | Val Loss: 0.6551, Val Acc: 0.87
# Epoch [19/20]: Train Loss: 0.0866, Train Acc: 0.97 | Val Loss: 0.5082, Val Acc: 0.89
# Epoch [20/20]: Train Loss: 0.0883, Train Acc: 0.97 | Val Loss: 0.5341, Val Acc: 0.87
# Training Complete!
# CPU times: total: 1h 18min 30s
# Wall time: 25min 43s

# %% [markdown]
# ## Learning rate changes

# %%
LR = 5e-5

# %%
model_v4_2 = CNN_3blocks(6).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_v4_2.parameters(), lr=LR)

# %%
# %%time 
EPOCHS = 20
metrics_v4_2 = train_model(model_v4_2, train_loader, val_loader, EPOCHS)
# Out:
# Epoch [1/20]: Train Loss: 0.8765, Train Acc: 0.67 | Val Loss: 0.6084, Val Acc: 0.78
# Epoch [2/20]: Train Loss: 0.6171, Train Acc: 0.77 | Val Loss: 0.6660, Val Acc: 0.77
# Epoch [3/20]: Train Loss: 0.5428, Train Acc: 0.80 | Val Loss: 0.4603, Val Acc: 0.83
# Epoch [4/20]: Train Loss: 0.4862, Train Acc: 0.82 | Val Loss: 0.4683, Val Acc: 0.83
# Epoch [5/20]: Train Loss: 0.4538, Train Acc: 0.83 | Val Loss: 0.4304, Val Acc: 0.85
# Epoch [6/20]: Train Loss: 0.4406, Train Acc: 0.84 | Val Loss: 0.4575, Val Acc: 0.84
# Epoch [7/20]: Train Loss: 0.3957, Train Acc: 0.85 | Val Loss: 0.4356, Val Acc: 0.85
# Epoch [8/20]: Train Loss: 0.3903, Train Acc: 0.86 | Val Loss: 0.3898, Val Acc: 0.86
# Epoch [9/20]: Train Loss: 0.3706, Train Acc: 0.86 | Val Loss: 0.3729, Val Acc: 0.87
# Epoch [10/20]: Train Loss: 0.3485, Train Acc: 0.87 | Val Loss: 0.3902, Val Acc: 0.86
# Epoch [11/20]: Train Loss: 0.3258, Train Acc: 0.88 | Val Loss: 0.3885, Val Acc: 0.87
# Epoch [12/20]: Train Loss: 0.3136, Train Acc: 0.88 | Val Loss: 0.3680, Val Acc: 0.87
# Epoch [13/20]: Train Loss: 0.2986, Train Acc: 0.89 | Val Loss: 0.3923, Val Acc: 0.86
# Epoch [14/20]: Train Loss: 0.2876, Train Acc: 0.89 | Val Loss: 0.3866, Val Acc: 0.87
# Epoch [15/20]: Train Loss: 0.2647, Train Acc: 0.90 | Val Loss: 0.4301, Val Acc: 0.86
# Epoch [16/20]: Train Loss: 0.2554, Train Acc: 0.91 | Val Loss: 0.3697, Val Acc: 0.88
# Epoch [17/20]: Train Loss: 0.2402, Train Acc: 0.91 | Val Loss: 0.3983, Val Acc: 0.87
# Epoch [18/20]: Train Loss: 0.2271, Train Acc: 0.92 | Val Loss: 0.3853, Val Acc: 0.87
# Epoch [19/20]: Train Loss: 0.2155, Train Acc: 0.92 | Val Loss: 0.3823, Val Acc: 0.87
# Epoch [20/20]: Train Loss: 0.2129, Train Acc: 0.92 | Val Loss: 0.4571, Val Acc: 0.85
# Training Complete!
# CPU times: total: 1h 17min 38s
# Wall time: 25min 28s

# %%
visualize(model_v4_2, metrics_v4_2)

# %%
LR = 1e-4
model_v4_3 = CNN_3blocks(6).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_v4_3.parameters(), lr=LR)

# %%
# %%time 
EPOCHS = 30
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.2)
metrics_v4_3 = train_model(model_v4_3, train_loader, val_loader, EPOCHS, dynamic_lr=True, scheduler=scheduler)
# Out:
# Epoch [1/30]: Train Loss: 0.8830, Train Acc: 0.66 | Val Loss: 0.5512, Val Acc: 0.80
# Epoch [2/30]: Train Loss: 0.6110, Train Acc: 0.78 | Val Loss: 0.5026, Val Acc: 0.82
# Epoch [3/30]: Train Loss: 0.5282, Train Acc: 0.81 | Val Loss: 0.6271, Val Acc: 0.78
# Epoch [4/30]: Train Loss: 0.4891, Train Acc: 0.82 | Val Loss: 0.4831, Val Acc: 0.84
# Epoch [5/30]: Train Loss: 0.4460, Train Acc: 0.84 | Val Loss: 0.4225, Val Acc: 0.85
# Epoch [6/30]: Train Loss: 0.3597, Train Acc: 0.87 | Val Loss: 0.3855, Val Acc: 0.87
# Epoch [7/30]: Train Loss: 0.3426, Train Acc: 0.88 | Val Loss: 0.3728, Val Acc: 0.87
# Epoch [8/30]: Train Loss: 0.3301, Train Acc: 0.88 | Val Loss: 0.3779, Val Acc: 0.87
# Epoch [9/30]: Train Loss: 0.3193, Train Acc: 0.88 | Val Loss: 0.3743, Val Acc: 0.87
# Epoch [10/30]: Train Loss: 0.3082, Train Acc: 0.89 | Val Loss: 0.3571, Val Acc: 0.88
# Epoch [11/30]: Train Loss: 0.2856, Train Acc: 0.90 | Val Loss: 0.3541, Val Acc: 0.88
# Epoch [12/30]: Train Loss: 0.2767, Train Acc: 0.90 | Val Loss: 0.3616, Val Acc: 0.88
# Epoch [13/30]: Train Loss: 0.2761, Train Acc: 0.90 | Val Loss: 0.3449, Val Acc: 0.88
# Epoch [14/30]: Train Loss: 0.2734, Train Acc: 0.90 | Val Loss: 0.3454, Val Acc: 0.88
# Epoch [15/30]: Train Loss: 0.2677, Train Acc: 0.90 | Val Loss: 0.3480, Val Acc: 0.88
# Epoch [16/30]: Train Loss: 0.2653, Train Acc: 0.91 | Val Loss: 0.3551, Val Acc: 0.88
# Epoch [17/30]: Train Loss: 0.2669, Train Acc: 0.90 | Val Loss: 0.3530, Val Acc: 0.88
# Epoch [18/30]: Train Loss: 0.2623, Train Acc: 0.90 | Val Loss: 0.3505, Val Acc: 0.88
# Epoch [19/30]: Train Loss: 0.2647, Train Acc: 0.91 | Val Loss: 0.3542, Val Acc: 0.88
# Epoch [20/30]: Train Loss: 0.2632, Train Acc: 0.90 | Val Loss: 0.3502, Val Acc: 0.88
# Epoch [21/30]: Train Loss: 0.2622, Train Acc: 0.91 | Val Loss: 0.3539, Val Acc: 0.88
# Epoch [22/30]: Train Loss: 0.2657, Train Acc: 0.91 | Val Loss: 0.3534, Val Acc: 0.88
# Epoch [23/30]: Train Loss: 0.2662, Train Acc: 0.90 | Val Loss: 0.3547, Val Acc: 0.88
# Epoch [24/30]: Train Loss: 0.2565, Train Acc: 0.91 | Val Loss: 0.3494, Val Acc: 0.88
# Epoch [25/30]: Train Loss: 0.2604, Train Acc: 0.90 | Val Loss: 0.3463, Val Acc: 0.88
# Epoch [26/30]: Train Loss: 0.2606, Train Acc: 0.91 | Val Loss: 0.3597, Val Acc: 0.88
# Epoch [27/30]: Train Loss: 0.2570, Train Acc: 0.91 | Val Loss: 0.3525, Val Acc: 0.88
# Epoch [28/30]: Train Loss: 0.2628, Train Acc: 0.91 | Val Loss: 0.3555, Val Acc: 0.88
# Epoch [29/30]: Train Loss: 0.2636, Train Acc: 0.91 | Val Loss: 0.3486, Val Acc: 0.88
# Epoch [30/30]: Train Loss: 0.2633, Train Acc: 0.91 | Val Loss: 0.3586, Val Acc: 0.87
# Training Complete!
# CPU times: total: 2h 22min 30s
# Wall time: 38min 15s

# %%
visualize(model_v4_3, metrics_v4_3)

# %%
optimizer.param_groups[0]['lr']
# Out:
# 6.4000000000000035e-09

# %%
# %%time 
EPOCHS = 20
optimizer = torch.optim.Adam(model_v4_3.parameters(), lr=LR*1e-1)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
metrics_v4_3_2 = train_model(model_v4_3, train_loader, val_loader, EPOCHS, dynamic_lr=True, scheduler=scheduler)
# Out:
# Current LR: 0.000010
# Epoch [1/20]: Train Loss: 0.2735, Train Acc: 0.90 | Val Loss: 0.3674, Val Acc: 0.87
# Current LR: 0.000010
# Epoch [2/20]: Train Loss: 0.2715, Train Acc: 0.90 | Val Loss: 0.3468, Val Acc: 0.88
# Current LR: 0.000010
# Epoch [3/20]: Train Loss: 0.2663, Train Acc: 0.90 | Val Loss: 0.3439, Val Acc: 0.88
# Current LR: 0.000010
# Epoch [4/20]: Train Loss: 0.2594, Train Acc: 0.91 | Val Loss: 0.3385, Val Acc: 0.89
# Current LR: 0.000005
# Epoch [5/20]: Train Loss: 0.2534, Train Acc: 0.91 | Val Loss: 0.3580, Val Acc: 0.88
# Current LR: 0.000005
# Epoch [6/20]: Train Loss: 0.2497, Train Acc: 0.91 | Val Loss: 0.3492, Val Acc: 0.88
# Current LR: 0.000005
# Epoch [7/20]: Train Loss: 0.2419, Train Acc: 0.91 | Val Loss: 0.3406, Val Acc: 0.88
# Current LR: 0.000005
# Epoch [8/20]: Train Loss: 0.2395, Train Acc: 0.91 | Val Loss: 0.3511, Val Acc: 0.88
# Current LR: 0.000005
# Epoch [9/20]: Train Loss: 0.2378, Train Acc: 0.91 | Val Loss: 0.3451, Val Acc: 0.88
# Current LR: 0.000003
# Epoch [10/20]: Train Loss: 0.2361, Train Acc: 0.92 | Val Loss: 0.3405, Val Acc: 0.88
# Current LR: 0.000003
# Epoch [11/20]: Train Loss: 0.2306, Train Acc: 0.92 | Val Loss: 0.3348, Val Acc: 0.89
# Current LR: 0.000003
# Epoch [12/20]: Train Loss: 0.2240, Train Acc: 0.92 | Val Loss: 0.3488, Val Acc: 0.88
# Current LR: 0.000003
# Epoch [13/20]: Train Loss: 0.2227, Train Acc: 0.92 | Val Loss: 0.3499, Val Acc: 0.88
# Current LR: 0.000003
# Epoch [14/20]: Train Loss: 0.2291, Train Acc: 0.92 | Val Loss: 0.3436, Val Acc: 0.88
# Current LR: 0.000001
# Epoch [15/20]: Train Loss: 0.2302, Train Acc: 0.92 | Val Loss: 0.3429, Val Acc: 0.89
# Current LR: 0.000001
# Epoch [16/20]: Train Loss: 0.2206, Train Acc: 0.92 | Val Loss: 0.3418, Val Acc: 0.89
# Current LR: 0.000001
# Epoch [17/20]: Train Loss: 0.2228, Train Acc: 0.92 | Val Loss: 0.3400, Val Acc: 0.89
# Current LR: 0.000001
# Epoch [18/20]: Train Loss: 0.2215, Train Acc: 0.92 | Val Loss: 0.3436, Val Acc: 0.89
# Current LR: 0.000001
# Epoch [19/20]: Train Loss: 0.2184, Train Acc: 0.92 | Val Loss: 0.3353, Val Acc: 0.89
# Current LR: 0.000001
# Epoch [20/20]: Train Loss: 0.2197, Train Acc: 0.92 | Val Loss: 0.3407, Val Acc: 0.89
# Training Complete!
# CPU times: total: 1h 31min 29s
# Wall time: 24min 52s

# %%
for i in range(6):
    metrics_v4_3[i] = metrics_v4_3[i] + metrics_v4_3_2[i]

# %%
visualize_scores(metrics_v4_3)

# %%
# torch.save({
#     'model_state_dict': model_v4_3.state_dict(),
#     'optimizer_state_dict': optimizer.state_dict(),
#     'metrics': metrics_v4_3
# }, 'models/v4_3.pth')
